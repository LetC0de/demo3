# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset.csv.txt")

# %%
df
# Out:
#     ID       Name     Age     Salary   Joining_Date Department  \
# 0    1       John      28    50000.0     2018-01-15      Sales
# 1    2      Alice     NaN    62000.0     2019/03/22         HR
# 2    3        Bob  Thirty  1000000.0            NaT         IT
# 3    4      Grace    27.5    -5000.0    InvalidDate        NaN
# 4    5    Michael      45    75000.0     2020-12-01    Finance
# 5    6      Sarah     -25    48000.0     2022/07/15  Marketing
# 6    7      David      32        NaN     2017-05-30      Sales
# 7    8       Emma      29    55000.0  Not Available         HR
# 8    9     Robert     999   120000.0     2023-02-28         IT
# 9   10       Lisa      26    42000.0     2021-11-11      Sales
# 10  11      James      31    68000.0     2019-08-25        NaN
# 11  12     Sophia      24    51000.0     2022-03-15  Marketing
# 12  13    William       0    59000.0     2018-09-10    Finance
# 13  14     Olivia      28    47000.0     2020-01-01         HR
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Salary', 'Joining_Date', 'Department', 'Email',
#        'Phone_Number', 'Gender', 'Performance_Score', 'Manager', 'Remarks'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID     Name     Age     Salary Joining_Date Department  \
# 0   1     John      28    50000.0   2018-01-15      Sales
# 1   2    Alice     NaN    62000.0   2019/03/22         HR
# 2   3      Bob  Thirty  1000000.0          NaT         IT
# 3   4    Grace    27.5    -5000.0  InvalidDate        NaN
# 4   5  Michael      45    75000.0   2020-12-01    Finance
#
#                  Email    Phone_Number   Gender Performance_Score Manager  \
# 0        john@mail.com  +91-9876543210        M                 A   Alice
# 1        alice(at)mail          123456   Female         Excellent     Bob
# 2                  NaN             NaN  Unknown                95     Eve
# 3     [grace@mail.com]     99999-99999        F                 B     NaN
# 4  michael@company.com     +1-555-0123        M                 A   Carol
#
#              Remarks
# 0               Good
# 1                  ?
# 2  Needs Improvement
# 3               Poor
# 4          Excellent

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (25, 12)

# %%
df.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  1
# Salary               2
# Joining_Date         0
# Department           2
# Email                1
# Phone_Number         1
# Gender               0
# Performance_Score    1
# Manager              2
# Remarks              5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 25 non-null     int64
#  1   Name               25 non-null     object
#  2   Age                24 non-null     object
#  3   Salary             23 non-null     float64
#  4   Joining_Date       25 non-null     object
#  5   Department         23 non-null     object
#  6   Email              24 non-null     object
#  7   Phone_Number       24 non-null     object
#  8   Gender             25 non-null     object
#  9   Performance_Score  24 non-null     object
#  10  Manager            23 non-null     object
#  11  Remarks            20 non-null     object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#               ID          Salary
# count  25.000000       23.000000
# mean   13.000000    99826.086957
# std     7.359801   197398.915944
# min     1.000000    -5000.000000
# 25%     7.000000    50500.000000
# 50%    13.000000    58000.000000
# 75%    19.000000    69500.000000
# max    25.000000  1000000.000000

# %%
df[df["Salary"] > 100000]
# Out:
#    ID    Name     Age     Salary Joining_Date Department               Email  \
# 2   3     Bob  Thirty  1000000.0          NaT         IT                 NaN
# 8   9  Robert     999   120000.0   2023-02-28         IT  robert@company.com
#
#       Phone_Number   Gender Performance_Score Manager            Remarks
# 2              NaN  Unknown                95     Eve  Needs Improvement
# 8  +61-2-9876-5432        M                 A   Carol        Outstanding

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# ID                    0.0
# Name                  0.0
# Age                   4.0
# Salary                8.0
# Joining_Date          0.0
# Department            8.0
# Email                 4.0
# Phone_Number          4.0
# Gender                0.0
# Performance_Score     4.0
# Manager               8.0
# Remarks              20.0
# dtype: float64

# %%
df["Salary"].fillna(df["Salary"].mean() , inplace=True)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_6560\2262915029.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Salary"].fillna(df["Salary"].mean() , inplace=True)

# %%
df.replace([np.inf,-np.inf],np.nan,inplace=True)

# %%
df
# Out:
#     ID       Name     Age          Salary   Joining_Date Department  \
# 0    1       John      28    50000.000000     2018-01-15      Sales
# 1    2      Alice     NaN    62000.000000     2019/03/22         HR
# 2    3        Bob  Thirty  1000000.000000            NaT         IT
# 3    4      Grace    27.5    -5000.000000    InvalidDate        NaN
# 4    5    Michael      45    75000.000000     2020-12-01    Finance
# 5    6      Sarah     -25    48000.000000     2022/07/15  Marketing
# 6    7      David      32    99826.086957     2017-05-30      Sales
# 7    8       Emma      29    55000.000000  Not Available         HR
# 8    9     Robert     999   120000.000000     2023-02-28         IT
# 9   10       Lisa      26    42000.000000     2021-11-11      Sales
# 10  11      James      31    68000.000000     2019-08-25        NaN
# 11  12     Sophia      24    51000.000000     2022-03-15  Marketing
# 12  13    William       0    59000.000000     2018-09-10    Finance
# ...

# %%
df["Age"]=pd.to_numeric(df["Age"],errors="coerce")

# %%
df
# Out:
#     ID       Name    Age          Salary   Joining_Date Department  \
# 0    1       John   28.0    50000.000000     2018-01-15      Sales
# 1    2      Alice    NaN    62000.000000     2019/03/22         HR
# 2    3        Bob    NaN  1000000.000000            NaT         IT
# 3    4      Grace   27.5    -5000.000000    InvalidDate        NaN
# 4    5    Michael   45.0    75000.000000     2020-12-01    Finance
# 5    6      Sarah  -25.0    48000.000000     2022/07/15  Marketing
# 6    7      David   32.0    99826.086957     2017-05-30      Sales
# 7    8       Emma   29.0    55000.000000  Not Available         HR
# 8    9     Robert  999.0   120000.000000     2023-02-28         IT
# 9   10       Lisa   26.0    42000.000000     2021-11-11      Sales
# 10  11      James   31.0    68000.000000     2019-08-25        NaN
# 11  12     Sophia   24.0    51000.000000     2022-03-15  Marketing
# 12  13    William    0.0    59000.000000     2018-09-10    Finance
# ...

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_6560\2595122914.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace=True)

# %%
df
# Out:
#     ID       Name         Age          Salary   Joining_Date Department  \
# 0    1       John   28.000000    50000.000000     2018-01-15      Sales
# 1    2      Alice   68.021739    62000.000000     2019/03/22         HR
# 2    3        Bob   68.021739  1000000.000000            NaT         IT
# 3    4      Grace   27.500000    -5000.000000    InvalidDate        NaN
# 4    5    Michael   45.000000    75000.000000     2020-12-01    Finance
# 5    6      Sarah  -25.000000    48000.000000     2022/07/15  Marketing
# 6    7      David   32.000000    99826.086957     2017-05-30      Sales
# 7    8       Emma   29.000000    55000.000000  Not Available         HR
# 8    9     Robert  999.000000   120000.000000     2023-02-28         IT
# 9   10       Lisa   26.000000    42000.000000     2021-11-11      Sales
# 10  11      James   31.000000    68000.000000     2019-08-25        NaN
# 11  12     Sophia   24.000000    51000.000000     2022-03-15  Marketing
# ...

# %%
df["Age"]=df["Age"].astype(int)

# %%
df
# Out:
#     ID       Name  Age          Salary   Joining_Date Department  \
# 0    1       John   28    50000.000000     2018-01-15      Sales
# 1    2      Alice   68    62000.000000     2019/03/22         HR
# 2    3        Bob   68  1000000.000000            NaT         IT
# 3    4      Grace   27    -5000.000000    InvalidDate        NaN
# 4    5    Michael   45    75000.000000     2020-12-01    Finance
# 5    6      Sarah  -25    48000.000000     2022/07/15  Marketing
# 6    7      David   32    99826.086957     2017-05-30      Sales
# 7    8       Emma   29    55000.000000  Not Available         HR
# 8    9     Robert  999   120000.000000     2023-02-28         IT
# 9   10       Lisa   26    42000.000000     2021-11-11      Sales
# 10  11      James   31    68000.000000     2019-08-25        NaN
# 11  12     Sophia   24    51000.000000     2022-03-15  Marketing
# 12  13    William    0    59000.000000     2018-09-10    Finance
# ...

# %%
df["Salary"]=df["Salary"].astype(int)

# %%
df
# Out:
#     ID       Name  Age   Salary   Joining_Date Department  \
# 0    1       John   28    50000     2018-01-15      Sales
# 1    2      Alice   68    62000     2019/03/22         HR
# 2    3        Bob   68  1000000            NaT         IT
# 3    4      Grace   27    -5000    InvalidDate        NaN
# 4    5    Michael   45    75000     2020-12-01    Finance
# 5    6      Sarah  -25    48000     2022/07/15  Marketing
# 6    7      David   32    99826     2017-05-30      Sales
# 7    8       Emma   29    55000  Not Available         HR
# 8    9     Robert  999   120000     2023-02-28         IT
# 9   10       Lisa   26    42000     2021-11-11      Sales
# 10  11      James   31    68000     2019-08-25        NaN
# 11  12     Sophia   24    51000     2022-03-15  Marketing
# 12  13    William    0    59000     2018-09-10    Finance
# 13  14     Olivia   28    47000     2020-01-01         HR
# 14  15      Ethan   33    99826     2016-12-05         IT
# ...

# %%
df=df.drop_duplicates(subset=["Name","Age","Salary","Joining_Date","Department","Email","Phone_Number","Gender","Performance_Score","Manager","Remarks"])

# %%
df
# Out:
#     ID       Name  Age   Salary   Joining_Date Department  \
# 0    1       John   28    50000     2018-01-15      Sales
# 1    2      Alice   68    62000     2019/03/22         HR
# 2    3        Bob   68  1000000            NaT         IT
# 3    4      Grace   27    -5000    InvalidDate        NaN
# 4    5    Michael   45    75000     2020-12-01    Finance
# 5    6      Sarah  -25    48000     2022/07/15  Marketing
# 6    7      David   32    99826     2017-05-30      Sales
# 7    8       Emma   29    55000  Not Available         HR
# 8    9     Robert  999   120000     2023-02-28         IT
# 9   10       Lisa   26    42000     2021-11-11      Sales
# 10  11      James   31    68000     2019-08-25        NaN
# 11  12     Sophia   24    51000     2022-03-15  Marketing
# 12  13    William    0    59000     2018-09-10    Finance
# 13  14     Olivia   28    47000     2020-01-01         HR
# 14  15      Ethan   33    99826     2016-12-05         IT
# ...

# %%
placeholders =['Not Available','Not available','InvalidDate','Invalid date','?','NaT','[]','NAN']
df.replace(placeholders,np.nan,inplace=True)

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019/03/22         HR         alice(at)mail
# 2    3        Bob   68  1000000          NaN         IT                   NaN
# 3    4      Grace   27    -5000          NaN        NaN      [grace@mail.com]
# 4    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 5    6      Sarah  -25    48000   2022/07/15  Marketing            sarah@mail
# 6    7      David   32    99826   2017-05-30      Sales     david@company.com
# 7    8       Emma   29    55000          NaN         HR         emma@mail.com
# 8    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 9   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 10  11      James   31    68000   2019-08-25        NaN     james@company.com
# ...

# %%
missing_values=df.isnull()
for col in df.columns:
    
    print(missing_values[col].value_counts())
    print(" ")
# Out:
# ID
# False    25
# Name: count, dtype: int64
#
# Name
# False    25
# Name: count, dtype: int64
#
# Age
# False    25
# Name: count, dtype: int64
#
# Salary
# False    25
# Name: count, dtype: int64
#
# Joining_Date
# False    21
# True      4
# Name: count, dtype: int64
#
# Department
# False    23
# True      2
# Name: count, dtype: int64
#
# Email
# False    24
# True      1
# Name: count, dtype: int64
#
# Phone_Number
# False    24
# True      1
# Name: count, dtype: int64
#
# Gender
# False    25
# Name: count, dtype: int64
#
# Performance_Score
# False    24
# True      1
# Name: count, dtype: int64
#
# Manager
# False    23
# True      2
# Name: count, dtype: int64
#
# Remarks
# False    19
# True      6
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Salary               0
# Joining_Date         4
# Department           2
# Email                1
# Phone_Number         1
# Gender               0
# Performance_Score    1
# Manager              2
# Remarks              6
# dtype: int64

# %%
df.dropna(subset=['Department'], inplace=True,axis=0)

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019/03/22         HR         alice(at)mail
# 2    3        Bob   68  1000000          NaN         IT                   NaN
# 4    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 5    6      Sarah  -25    48000   2022/07/15  Marketing            sarah@mail
# 6    7      David   32    99826   2017-05-30      Sales     david@company.com
# 7    8       Emma   29    55000          NaN         HR         emma@mail.com
# 8    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 9   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 11  12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 12  13    William    0    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019/03/22         HR         alice(at)mail
# 2    3        Bob   68  1000000          NaN         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah  -25    48000   2022/07/15  Marketing            sarah@mail
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000          NaN         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William    0    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df["Age"] = np.where(df['Age'] <0,df["Age"].mean(),df["Age"])

# %%
df["Age"] = np.where(df["Age"] ==0 ,df["Age"].mean(),df["Age"])

# %%
df['Age']=df["Age"].astype(int)

# %%
df['Age']= pd.to_numeric(df['Age'],errors='coerce')

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019/03/22         HR         alice(at)mail
# 2    3        Bob   68  1000000          NaN         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022/07/15  Marketing            sarah@mail
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000          NaN         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df['Joining_Date'].isna().sum()
# Out:
# np.int64(0)

# %%
joining_dates = [
    "2018-01-15", "2019/03/22", "NaN", "2020-12-01", "2022/07/15",
    "2017-05-30", "NaN", "2023-02-28", "2021-11-11", "2022-03-15",
    "2018-09-10", "2020-01-01", "2016-12-05", "2021/06/30", "2019-04-22",
    "2022-08-14", "2017-11-30", "2020-05-15", "NaN", "2018-07-07",
    "2015-03-12", "2021-02-28", "2019-10-31"
]

# Insert into new column 'Joining_Date'
df["Joining_Date"] = joining_dates

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019/03/22         HR         alice(at)mail
# 2    3        Bob   68  1000000          NaN         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022/07/15  Marketing            sarah@mail
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000          NaN         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df['Joining_Date'] = df['Joining_Date'].astype(str).str.strip()

# %%
df['Joining_Date'] = df['Joining_Date'].str.replace('/', '-', regex=False)
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], errors='coerce')

# %%
# df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], format='%Y/%m/%d', errors='coerce')

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019-03-22         HR         alice(at)mail
# 2    3        Bob   68  1000000          NaT         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022-07-15  Marketing            sarah@mail
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000          NaT         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df["Joining_Date"].isna().sum()
# Out:
# np.int64(3)

# %%
df['Joining_Date'] = df.groupby('Department')['Joining_Date'].transform(lambda x: x.fillna(x.median()))

# %%
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], errors='coerce').dt.date

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019-03-22         HR         alice(at)mail
# 2    3        Bob   68  1000000   2020-02-06         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022-07-15  Marketing            sarah@mail
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019-03-22         HR         alice(at)mail
# 2    3        Bob   68  1000000   2020-02-06         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022-07-15  Marketing            sarah@mail
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df.drop('Valid_Email',axis=1,inplace=True)

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019-03-22         HR         alice(at)mail
# 2    3        Bob   68  1000000   2020-02-06         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022-07-15  Marketing            sarah@mail
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df['Email'] = df['Email'].str.replace(r'\(at\)', '@', regex=True)
df['Email'] = df['Email'].apply(lambda x: x + ".com" if pd.notna(x) and "@" in x and "." not in x else x)

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019-03-22         HR        alice@mail.com
# 2    3        Bob   68  1000000   2020-02-06         IT                   NaN
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022-07-15  Marketing        sarah@mail.com
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df['Email'] = df['Email'].fillna('unknown@mail.com')

# %%
df
# Out:
#     ID       Name  Age   Salary Joining_Date Department                 Email  \
# 0    1       John   28    50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68    62000   2019-03-22         HR        alice@mail.com
# 2    3        Bob   68  1000000   2020-02-06         IT      unknown@mail.com
# 3    5    Michael   45    75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71    48000   2022-07-15  Marketing        sarah@mail.com
# 5    7      David   32    99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29    55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999   120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26    42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24    51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75    59000   2018-09-10    Finance   william@company.com
# ...

# %%
df.drop(2,axis=0,inplace=True)

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 3    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 5    7      David   32   99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999  120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75   59000   2018-09-10    Finance   william@company.com
# 11  14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].astype(str).str.replace(r'\D', '', regex=True)

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 3    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 5    7      David   32   99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999  120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75   59000   2018-09-10    Finance   william@company.com
# 11  14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].apply(
    lambda x: '+91' + x if len(x) == 10 else '+' + x
)

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 3    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 5    7      David   32   99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999  120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75   59000   2018-09-10    Finance   william@company.com
# 11  14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# ...

# %%
df['Gender'] = df['Gender'].replace({'Female':'F'})

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 3    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 5    7      David   32   99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999  120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75   59000   2018-09-10    Finance   william@company.com
# 11  14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# ...

# %%
df['Performance_Score'] = df['Performance_Score'].replace({'Excellent':'E'})

# %%
df['Performance_Score'] = df['Performance_Score'].fillna(df["Performance_Score"].mode()[0])

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 3    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 4    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 5    7      David   32   99826   2017-05-30      Sales     david@company.com
# 6    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 7    9     Robert  999  120000   2023-02-28         IT    robert@company.com
# 8   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 9   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 10  13    William   75   59000   2018-09-10    Finance   william@company.com
# 11  14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# ...

# %%
df['Remarks'] = df['Remarks'].fillna("No remarks")

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 2    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 3    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 4    7      David   32   99826   2017-05-30      Sales     david@company.com
# 5    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 6    9     Robert  999  120000   2023-02-28         IT    robert@company.com
# 7   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 8   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 9   13    William   75   59000   2018-09-10    Finance   william@company.com
# 10  14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# ...

# %%
age_mean = df['Age'].mean()
age_std = df['Age'].std()
lower_bound = age_mean - (3 * age_std)
upper_bound = age_mean + (3 * age_std)

# %%
df = df[(df["Age"] >= lower_bound) & (df["Age"] <= upper_bound )]

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 2    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 3    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 4    7      David   32   99826   2017-05-30      Sales     david@company.com
# 5    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 7   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 8   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 9   13    William   75   59000   2018-09-10    Finance   william@company.com
# 10  14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# 11  15      Ethan   33   99826   2016-12-05         IT     ethan@company.com
# ...

# %%
salary_mean = df['Salary'].mean()
salary_std = df['Salary'].std()
lower_bound = salary_mean - (3 * salary_std)
upper_bound = salary_mean + (3 * salary_std)

# %%
df = df[(df["Salary"] >= lower_bound) & (df["Salary"] <= upper_bound )]

# %%
df
# Out:
#     ID       Name  Age  Salary Joining_Date Department                 Email  \
# 0    1       John   28   50000   2018-01-15      Sales         john@mail.com
# 1    2      Alice   68   62000   2019-03-22         HR        alice@mail.com
# 2    5    Michael   45   75000   2020-12-01    Finance   michael@company.com
# 3    6      Sarah   71   48000   2022-07-15  Marketing        sarah@mail.com
# 4    7      David   32   99826   2017-05-30      Sales     david@company.com
# 5    8       Emma   29   55000   2019-08-11         HR         emma@mail.com
# 6   10       Lisa   26   42000   2021-11-11      Sales         lisa@mail.com
# 7   12     Sophia   24   51000   2022-03-15  Marketing       sophia@mail.com
# 8   13    William   75   59000   2018-09-10    Finance   william@company.com
# 9   14     Olivia   28   47000   2020-01-01         HR       olivia@mail.com
# 10  15      Ethan   33   99826   2016-12-05         IT     ethan@company.com
# ...
